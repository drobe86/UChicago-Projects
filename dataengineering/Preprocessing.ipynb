# %%
#Importing Dataset
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
#Dale
#accepted_loans = pd.read_csv(r"C:\Users\drobey\Documents\Coding\Grad School\Data Platforms\Project\accepted_2007_to_2018Q4.csv")
#Frederick
accepted_loans = pd.read_csv(r"/Users/yumingz/Projects/DEPA/FinalProject/accepted_2007_to_2018Q4.csv")
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#View it
accepted_loans.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
#Get List of column names
list(accepted_loans.columns)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
# ...

# %%
#drop all rows we judgementally determined not to include
accepted_loans = accepted_loans.drop([
'all_util',
'avg_cur_bal',
'bc_open_to_buy',
'bc_util',
'chargeoff_within_12_mths',
'collection_recovery_fee',
'collections_12_mths_ex_med',
'delinq_2yrs',
'delinq_amnt',
'dti',
'dti_joint',
'earliest_cr_line',
'il_util',
'initial_list_status',
'last_credit_pull_d',
'last_fico_range_high',
'last_fico_range_low',
'last_pymnt_amnt',
'last_pymnt_d',
'max_bal_bc',
'member_id',
'mths_since_last_delinq',
'mths_since_last_major_derog',
'mths_since_recent_revol_delinq',
'next_pymnt_d',
'num_tl_90g_dpd_24m',
'open_il_24m',
'open_rv_24m',
'out_prncp',
'out_prncp_inv',
'policy_code',
'pymnt_plan',
'recoveries',
'revol_bal',
'revol_util',
'tax_liens',
'term',
'tot_coll_amt',
'tot_cur_bal',
'tot_hi_cred_lim',
'total_bal_ex_mort',
'total_bal_il',
'total_bc_limit',
'total_il_high_credit_limit',
'total_pymnt',
'total_pymnt_inv',
'total_rec_int',
'total_rec_late_fee',
'total_rec_prncp',
'total_rev_hi_lim',
'url',
'verification_status',
'verification_status_joint',
'zip_code',
'revol_bal_joint', 
'hardship_flag',
'hardship_type',
'hardship_reason',
'hardship_status',
'deferral_term',
'hardship_amount',
'hardship_start_date',
'hardship_end_date',
'payment_plan_start_date',
'hardship_length',
'hardship_dpd',
'hardship_loan_status',
'orig_projected_additional_accrued_interest',
'hardship_payoff_balance_amount',
'hardship_last_payment_amount',
'disbursement_method',
'debt_settlement_flag',
'debt_settlement_flag_date',
'settlement_status',
'settlement_date',
'settlement_amount',
'settlement_percentage',
'settlement_term',
'issue_d'], axis=1)

# %%
#Find which columns have a large amt of NA values
nan_mean = accepted_loans.isna().mean()
nan_mean = nan_mean[nan_mean != 0].sort_values()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(nan_mean)
# Out:
# loan_amnt                              0.000015
# addr_state                             0.000015
# purpose                                0.000015
# loan_status                            0.000015
# home_ownership                         0.000015
# fico_range_low                         0.000015
# application_type                       0.000015
# grade                                  0.000015
# installment                            0.000015
# int_rate                               0.000015
# funded_amnt_inv                        0.000015
# funded_amnt                            0.000015
# sub_grade                              0.000015
# fico_range_high                        0.000015
# annual_inc                             0.000016
# acc_now_delinq                         0.000027
# total_acc                              0.000027
# pub_rec                                0.000027
# open_acc                               0.000027
# inq_last_6mths                         0.000028
# ...

# %%
#Drop rows with NAs in these columns
accepted_loans.dropna(subset = ["loan_amnt","annual_inc","acc_now_delinq"], inplace=True)

# %%
#Drop rows related to secondary (very empty and would potentially throw off model)
accepted_loans = accepted_loans.drop([
'annual_inc_joint',                  
'sec_app_fico_range_low',                
'sec_app_fico_range_high',               
'sec_app_earliest_cr_line',              
'sec_app_inq_last_6mths',                
'sec_app_mort_acc',                      
'sec_app_open_acc',                      
'sec_app_open_act_il',                   
'sec_app_num_rev_accts',                 
'sec_app_chargeoff_within_12_mths',      
'sec_app_collections_12_mths_ex_med',    
'sec_app_revol_util',
'sec_app_mths_since_last_major_derog'], axis=1)

# %%
#Fill string NA rows with empty strings
#Fill columns related to months since XXX that have NA with the max amount (assumption we made) 
fill_empty = ['emp_title','title','desc']
fill_max = ['mo_sin_rcnt_tl', 'mo_sin_old_rev_tl_op',
            'mo_sin_rcnt_rev_tl_op', 'mths_since_recent_bc',
            'mo_sin_old_il_acct', 'mths_since_recent_inq', 'mths_since_recent_bc_dlq',
            'pct_tl_nvr_dlq','mths_since_rcnt_il','mths_since_last_record']


accepted_loans[fill_empty] = accepted_loans[fill_empty].fillna('')
accepted_loans[fill_max] = accepted_loans[fill_max].fillna(accepted_loans[fill_max].max())

# %%
#Fix some data issues with emp_lenth and id
accepted_loans['emp_length'] = accepted_loans['emp_length'].replace({'< 1 year': '0 years', '10+ years': '11 years'})
accepted_loans['emp_length'] = accepted_loans['emp_length'].str.extract('(\d+)').astype('float')
accepted_loans['id'] = accepted_loans['id'].astype('float')

# %%
#Fill columns related to "num of XXX" to 0 if NA
fill_min = ['inq_last_6mths',
'pub_rec_bankruptcies',                  
'mort_acc',                              
'acc_open_past_24mths',                  
'num_bc_sats',                           
'num_sats',                              
'num_actv_bc_tl',                        
'num_accts_ever_120_pd',                 
'num_bc_tl',                             
'num_op_rev_tl',                         
'num_actv_rev_tl',                       
'num_rev_tl_bal_gt_0',                   
'num_tl_30dpd',                          
'num_tl_op_past_12m',                    
'num_il_tl',                             
'num_rev_accts',                         
'percent_bc_gt_75',                      
'emp_length',                            
'num_tl_120dpd_2m',                      
'inq_fi',                                
'open_rv_12m',                           
'open_il_12m',                           
'open_act_il',                           
'total_cu_tl',                           
'open_acc_6m',                           
'inq_last_12m']


accepted_loans[fill_min] = accepted_loans[fill_min].fillna(accepted_loans[fill_min].min())

# %%
#Make sure we have taken care of all NA values
nan_mean = accepted_loans.isna().mean()
nan_mean = nan_mean[nan_mean != 0].sort_values()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(nan_mean)
# Out:
# Series([], dtype: float64)

# %%
accepted_loans.head()
accepted_loans.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'loan_status', 'desc', 'purpose',
#        'title', 'addr_state', 'fico_range_low', 'fico_range_high',
#        'inq_last_6mths', 'mths_since_last_record', 'open_acc', 'pub_rec',
#        'total_acc', 'application_type', 'acc_now_delinq', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'mths_since_rcnt_il', 'open_rv_12m',
#        'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths',
#        'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op',
#        'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc',
#        'mths_since_recent_bc_dlq', 'mths_since_recent_inq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
# ...

# %%
#Import operational data into mySQL
#Important to run SQL code before this though
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="rootroot",
                               db="loan_data_operational"))

accepted_loans.to_sql('loan_details_main', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# /usr/local/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# /usr/local/lib/python3.8/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     187             assert q_values[0] == '(' and q_values[-1] == ')'
# ...

# %%
import pymysql

# create connection
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='rootroot',
                             db='loan_data_operational')

# Create cursor
my_cursor = connection.cursor()

# Execute Query
my_cursor.execute("SELECT * from loan_details_main LIMIT 10")

# Fetch the records
result = my_cursor.fetchall()

for i in result:
    print(i)

# Close the connection
connection.close()

# %%
#See how many unique values each categorial variable has 
cat_feat = accepted_loans.select_dtypes('object').columns.values
accepted_loans[cat_feat].nunique().sort_values()
# Out:
# application_type         2
# home_ownership           6
# grade                    7
# loan_status              9
# purpose                 14
# sub_grade               35
# addr_state              51
# title                63142
# desc                124474
# emp_title           512682
# dtype: int64

# %%
#As we can see, title, desc and emp_title have a lot of different values.Would cause memory problems.
#Would be value in NLP with these columns, but beyond scope for us
#Also we want to get rid of sub_grade (we know is highly correlated with grade)
accepted_loans = accepted_loans.drop(['title', 'desc','emp_title','sub_grade'], axis=1, errors='ignore')

# %%
#Used to calculate pearson correlation between the various column
import numpy as np
from itertools import combinations
from scipy.stats import pearsonr
num_feat = accepted_loans.select_dtypes('number').columns.values
comb_num_feat = np.array(list(combinations(num_feat, 2)))
corr_num_feat = np.array([])
for comb in comb_num_feat:
    corr = pearsonr(accepted_loans[comb[0]], accepted_loans[comb[1]])[0]
    corr_num_feat = np.append(corr_num_feat, corr)

# %%
#Viewing these
high_corr_num = comb_num_feat[np.abs(corr_num_feat) >= 0.9]
high_corr_num
# Out:
# array([['loan_amnt', 'funded_amnt'],
#        ['loan_amnt', 'funded_amnt_inv'],
#        ['loan_amnt', 'installment'],
#        ['funded_amnt', 'funded_amnt_inv'],
#        ['funded_amnt', 'installment'],
#        ['funded_amnt_inv', 'installment'],
#        ['fico_range_low', 'fico_range_high'],
#        ['open_acc', 'num_sats'],
#        ['mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl'],
#        ['num_actv_rev_tl', 'num_rev_tl_bal_gt_0']], dtype='<U24')

# %%
#Dropping the second one in each pair bc I wanted to keep loan_amnt 
accepted_loans = accepted_loans.drop(np.unique(high_corr_num[:, 1]), axis=1, errors='ignore')

# %%
#How many loans are in each status
my_list = accepted_loans['loan_status'].value_counts()
my_list
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1962
# Does not meet the credit policy. Status:Charged Off        758
# Default                                                     40
# Name: loan_status, dtype: int64

# %%
#We considered loans with status Current, Fully Paid, and In Grace Period as good. 
#All the other statuses are considered as bad loans (late 16-30 days, Late 31-120 days, or default) 
y = accepted_loans['loan_status'].copy()
y = y.isin(['Current', 'Fully Paid','In Grace Period','Does not meet the credit policy. Status:Fully Paid']).astype('int')
y.value_counts()
# Out:
# 1    1965466
# 0     295173
# Name: loan_status, dtype: int64

# %%
X_f = accepted_loans['grade'].copy()

# %%
X_f.value_counts()
# Out:
# B    663547
# C    650047
# A    433016
# D    324423
# E    135638
# F     41800
# G     12168
# Name: grade, dtype: int64

# %%
#Only concerned with high risk/high reward loans. So we focus on grades with E F and G
#Remove grade/interest rate after selecting the high risk ones (and therefore high interest rate loans)
#Also remove loan status as that's now our y variable
X = accepted_loans[(accepted_loans.grade == 'E') | (accepted_loans.grade == 'F') | (accepted_loans.grade == 'G')].copy()
X.drop
X = X.drop(['grade', 'int_rate','loan_status','addr_state'], axis=1, errors='ignore')

# %%
#Also drop ID since it is no longer relevant
X = X.drop(['id'], axis = 1)

# %%
X.head()
# Out:
#     loan_amnt  emp_length home_ownership  annual_inc             purpose  \
# 4     10400.0         3.0       MORTGAGE    104433.0      major_purchase
# 13    18000.0         7.0           RENT    150000.0  debt_consolidation
# 19     8650.0         8.0           RENT     55000.0  debt_consolidation
# 31    24250.0         4.0       MORTGAGE     75000.0  debt_consolidation
# 48    14650.0         2.0           RENT     43160.0  debt_consolidation
#
#     fico_range_low  inq_last_6mths  mths_since_last_record  open_acc  pub_rec  \
# 4            695.0             3.0                   129.0      12.0      0.0
# 13           665.0             1.0                    75.0      18.0      1.0
# 19           675.0             4.0                    30.0      18.0      1.0
# 31           660.0             0.0                   129.0      18.0      0.0
# 48           690.0             0.0                   129.0      12.0      0.0
#
# ...

# %%
#Only get the y values for which there is an X
y_mod = y[X.index]

# %%
#Combining the y and X variables into one dataframe
X_2 = pd.concat([y_mod, X], axis=1)

# %%
#normalizing the data
from sklearn import preprocessing
X_3 = X_2.drop(['application_type', 'home_ownership','purpose'],axis=1)
X_array = X_3.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(X_array)
X_norm=pd.DataFrame(x_scaled, columns=X_3.columns)
X_norm.head()
# Out:
#    loan_status  loan_amnt  emp_length  annual_inc  fico_range_low  \
# 0          1.0   0.248731    0.272727    0.012286        0.361702
# 1          0.0   0.441624    0.636364    0.017647        0.234043
# 2          1.0   0.204315    0.727273    0.006471        0.276596
# 3          0.0   0.600254    0.363636    0.008824        0.212766
# 4          1.0   0.356599    0.181818    0.005078        0.340426
#
#    inq_last_6mths  mths_since_last_record  open_acc   pub_rec  total_acc  \
# 0        0.090909                1.000000  0.136364  0.000000   0.211180
# 1        0.030303                0.581395  0.204545  0.021277   0.161491
# 2        0.121212                0.232558  0.204545  0.021277   0.111801
# 3        0.000000                1.000000  0.204545  0.000000   0.124224
# 4        0.000000                1.000000  0.136364  0.000000   0.142857
#
#    acc_now_delinq  open_acc_6m  open_act_il  open_il_12m  mths_since_rcnt_il  \
# ...

# %%
#saving to csv (probably should put it back into SQL somehow?)
X_norm.to_csv(r'C:\Users\drobey\Documents\Coding\Grad School\Data Platforms\Project\accepted_loans_test_norm.csv')

# %%
#viewing the columns
X_norm.head()
# Out:
#    loan_status  loan_amnt  emp_length  annual_inc  fico_range_low  \
# 0          1.0   0.248731    0.272727    0.012286        0.361702
# 1          0.0   0.441624    0.636364    0.017647        0.234043
# 2          1.0   0.204315    0.727273    0.006471        0.276596
# 3          0.0   0.600254    0.363636    0.008824        0.212766
# 4          1.0   0.356599    0.181818    0.005078        0.340426
#
#    inq_last_6mths  mths_since_last_record  open_acc   pub_rec  total_acc  \
# 0        0.090909                1.000000  0.136364  0.000000   0.211180
# 1        0.030303                0.581395  0.204545  0.021277   0.161491
# 2        0.121212                0.232558  0.204545  0.021277   0.111801
# 3        0.000000                1.000000  0.204545  0.000000   0.124224
# 4        0.000000                1.000000  0.136364  0.000000   0.142857
#
#    acc_now_delinq  open_acc_6m  open_act_il  open_il_12m  mths_since_rcnt_il  \
# ...

# %%
#Import model data into mySQL
#Important to run SQL code before this though
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="rootroot",
                               db="loan_data_model"))

X_norm.to_sql('loan_details_model', con = engine, if_exists = 'append', chunksize = 1000, index = False)

# %%
#Check to make sure import worked
import pymysql

# create connection
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='rootroot',
                             db='loan_data_model')

# Create cursor
my_cursor = connection.cursor()

# Execute Query
my_cursor.execute("SELECT * from loan_details_model LIMIT 10")

# Fetch the records
result = my_cursor.fetchall()

for i in result:
    print(i)

# Close the connection
connection.close()
# Out:
# (1, 0.248731, 0.272727, 0.0122862, 0.361702, 0.0909091, 1.0, 0.136364, 0.0, 0.21118, 0.0, 0.0625, 0.0566038, 0.0, 0.0273973, 0.153846, 0.0714286, 0.012987, 0.075, 0.204082, 0.128128, 0.208626, 0.00731261, 0.115385, 0.00605144, 0.0594059, 0.04, 0.0, 0.137931, 0.12766, 0.0877193, 0.155172, 0.0757576, 0.104478, 0.188119, 0.0, 0.0, 0.142857, 0.966, 0.6, 0.0)
# (0, 0.441624, 0.636364, 0.0176471, 0.234043, 0.030303, 0.581395, 0.204545, 0.0212766, 0.161491, 0.0, 0.125, 0.0377358, 0.05, 0.00391389, 0.0769231, 0.0714286, 0.012987, 0.05, 0.142857, 0.115115, 0.110331, 0.00182815, 0.0384615, 0.0136157, 1.0, 0.08, 0.0, 0.206897, 0.276596, 0.122807, 0.137931, 0.0454545, 0.238806, 0.188119, 0.0, 0.0, 0.107143, 1.0, 0.143, 0.111111)
# ...
